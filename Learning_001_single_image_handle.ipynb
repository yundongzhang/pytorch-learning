# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import math

# %%
from PIL import Image

# %%
panda = np.array(Image.open('/Users/yundong.zhang/Downloads/screenshot-20230921-134840.jpg').resize((224,224)))
panda_tensor = torch.from_numpy(panda)
panda_tensor.size()
# Out:
# torch.Size([224, 224, 3])

# %%
plt.imshow(panda)

# %%
plt.imshow(panda_tensor[:,:,0].numpy())

# %%
plt.imshow(panda_tensor[25:200,60:200,0].numpy())

# %%
sales = torch.eye(3,3)
sales[0,1]
# Out:
# tensor(0.)
