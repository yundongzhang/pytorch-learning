# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from PIL import Image
import math
from glob import glob

# %%
cats = glob('resource/cat/*.jpg')

# %%
cat_images = np.array([np.array(Image.open(cat).resize((224,224))) for cat in cats[:64]])
cat_images = cat_images.reshape(-1,224,224,3)
cat_tensors = torch.from_numpy(cat_images)
cat_tensors.size()
